# %%
import pandas as pd
# dict타입으로 구성해서 2차원 데이터로 변환
data = {
  '이름':['강나래','강태원','강호림','김수찬','김재욱','박동현','박혜정','승근열'],
  '학교':['구로고','구로고','가산고','구로고','가산고','가산고','구로고','구로고'],
  '키':[197,184,168,187,188,202,188,190],
  '국어':[90,40,80,40,15,80,55,100],
  '영어':[85,35,75,60,20,100,65,85],
  '수학':[100,50,70,70,10,95,45,90],
  '사회':[85,25,75,80,10,80,35,95],
  'SW특기':['Python','Java','Javascript',' ',' ','C','PYTHON','C#']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  사회        SW특기
# 0  강나래  구로고  197   90   85  100  85      Python
# 1  강태원  구로고  184   40   35   50  25        Java
# 2  강호림  가산고  168   80   75   70  75  Javascript
# 3  김수찬  구로고  187   40   60   70  80
# 4  김재욱  가산고  188   15   20   10  10
# 5  박동현  가산고  202   80  100   95  80           C
# 6  박혜정  구로고  188   55   65   45  35      PYTHON
# 7  승근열  구로고  190  100   85   90  95          C#

# %%
# index 지정
df = pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
# index의 이름 지정
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  85      Python
# 2번    강태원  구로고  184   40   35   50  25        Java
# 3번    강호림  가산고  168   80   75   70  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  80
# 5번    김재욱  가산고  188   15   20   10  10
# 6번    박동현  가산고  202   80  100   95  80           C
# 7번    박혜정  구로고  188   55   65   45  35      PYTHON
# 8번    승근열  구로고  190  100   85   90  95          C#

# %%
# 컬럼의 전체값
df['이름']
# Out:
# 지원번호
# 1번    강나래
# 2번    강태원
# 3번    강호림
# 4번    김수찬
# 5번    김재욱
# 6번    박동현
# 7번    박혜정
# 8번    승근열
# Name: 이름, dtype: object

# %%
df['1번'] # DataFrame은 Series처럼 안되고 Column별로 불러와야함
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\KOSMO\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1번'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ...

# %%
df.loc['1번'] # index값을 입력, 1줄 학생의 값 가져오기
# Out:
# 이름         강나래
# 학교         구로고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  사회        SW특기
# 0   1번  강나래  구로고  197   90   85  100  85      Python
# 1   2번  강태원  구로고  184   40   35   50  25        Java
# 2   3번  강호림  가산고  168   80   75   70  75  Javascript
# 3   4번  김수찬  구로고  187   40   60   70  80
# 4   5번  김재욱  가산고  188   15   20   10  10
# 5   6번  박동현  가산고  202   80  100   95  80           C
# 6   7번  박혜정  구로고  188   55   65   45  35      PYTHON
# 7   8번  승근열  구로고  190  100   85   90  95          C#

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  85      Python
# 2번    강태원  구로고  184   40   35   50  25        Java
# 3번    강호림  가산고  168   80   75   70  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  80
# 5번    김재욱  가산고  188   15   20   10  10
# 6번    박동현  가산고  202   80  100   95  80           C
# 7번    박혜정  구로고  188   55   65   45  35      PYTHON
# 8번    승근열  구로고  190  100   85   90  95          C#

# %%
df = pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  85      Python
# 2번    강태원  구로고  184   40   35   50  25        Java
# 3번    강호림  가산고  168   80   75   70  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  80
# 5번    김재욱  가산고  188   15   20   10  10
# 6번    박동현  가산고  202   80  100   95  80           C
# 7번    박혜정  구로고  188   55   65   45  35      PYTHON
# 8번    승근열  구로고  190  100   85   90  95          C#

# %%
df.reset_index(drop=True,inplace=True) # drop:index삭제, inplace:적용
df
# Out:
#     이름   학교    키   국어   영어   수학  사회        SW특기
# 0  강나래  구로고  197   90   85  100  85      Python
# 1  강태원  구로고  184   40   35   50  25        Java
# 2  강호림  가산고  168   80   75   70  75  Javascript
# 3  김수찬  구로고  187   40   60   70  80
# 4  김재욱  가산고  188   15   20   10  10
# 5  박동현  가산고  202   80  100   95  80           C
# 6  박혜정  구로고  188   55   65   45  35      PYTHON
# 7  승근열  구로고  190  100   85   90  95          C#

# %%
df.set_index('이름',inplace=True)
df.sort_index(inplace=True) # inplace=True 설정이 변경됨.
df
# Out:
#       학교    키   국어   영어   수학  사회        SW특기
# 이름
# 강나래  구로고  197   90   85  100  85      Python
# 강태원  구로고  184   40   35   50  25        Java
# 강호림  가산고  168   80   75   70  75  Javascript
# 김수찬  구로고  187   40   60   70  80
# 김재욱  가산고  188   15   20   10  10
# 박동현  가산고  202   80  100   95  80           C
# 박혜정  구로고  188   55   65   45  35      PYTHON
# 승근열  구로고  190  100   85   90  95          C#

# %%
df.sort_index(inplace=True) # inplace=True 설정이 변경됨.
